# %% [markdown]
# <p style="padding: 10px; border: 1px solid black;">
# <img src=".././images/MLU-NEW-logo.png" alt="drawing" width="400"/> <br/>
#
# # MLU Day One Machine Learning - DEMO

# %%
# Load in libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as img
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## ML Problem Description
# Predict the Unit of measure (count, volume, weight) identification for a product from the Amazon Product Catalog.
# > This is a multiclass classification task (3 distinct classes). <br>
#
# The data for this ML problem has 32 features and 1 label column. Examples of features include:
#
#
# | Feature | Description |
# | :---        |    :----  |
# | marketplace_id | Marketplace ID.|
# | product_type   | Type of product.  |
# | item_name | Short item description. |
# | product_description   | Long item description.  |
# | bullet_point | Bullet point item description. |
# | brand   | Brand name.  |
# | manufacturer | Manufacturer name. |
# | ...   | ...  |
# | list_price_value_with_tax   | Price of item including tax.  |
# | imgID | ID for image of product. |
# | ID   | Product identifier.  |

# %% [markdown]
# ## 1. <a name="5">AutoGluon Installation</a>
#
# We need to begin by installing AutoGluon (documentation [here](https://auto.gluon.ai/stable/install.html)).
#
#
# __NOTE__: This may take a few minutes to install (you can see that it is finished once the `[*]` symbol next to the cell disappears and turns into a number).

# %%
# !python3 -m pip install -qU pip
# !python3 -m pip install -qU setuptools wheel
# !python3 -m pip install -qU "mxnet<2.0.0"
# !python3 -m pip install -qU autogluon

# %% [markdown]
# Now we load the libraries needed to work with our Tabular dataset.

# %%
from autogluon.tabular import TabularPredictor, TabularDataset

# %% [markdown]
# ___
# ## 2. <a name="5">Getting the Data</a>
# Let's create a small sample to quickly train with AutoGluon and look at the first few rows of data.

# %%
train = TabularDataset(".././datasets/uomi-train.csv")
test = TabularDataset(".././datasets/uomi-test.csv")

# %%
# Print size of training set
print(f"Size of training set: {len(train)}")

# Show the first rows of training data
train.head(2)
# Out:
# Size of training set: 28305
#       ID  marketplace_id  label product_type  \
# 0   1633               1      1      GROCERY
# 1  18103               1      2      GROCERY
#
#                                            item_name  \
# 0        JELL-O Play Ocean Build + Eat Kit, 6 oz Box
# 1  Crystal Light Pure Variety Pack includes- Rasp...
#
#                                  product_description  \
# 0                                                NaN
# 1  With no artificial sweeteners, flavors or pres...
#
#                                         bullet_point          brand  \
# 0        One 6 oz. JELL-O Play Ocean Build + Eat Kit    Jell-O Play
# 1  Customer Will Receive 6 Boxes Total - 1 Raspbe...  Crystal Light
#
#     manufacturer part_number  ... item_dimensions_height  \
# 0         Jell-o  4300008150  ...                  2.625
# 1  Crystal Light         NaN  ...                    NaN
#
#   item_dimensions_width item_dimensions_length normalized_item_weight  \
# 0                 6.625                    8.5               0.023438
# 1                   NaN                    NaN                    NaN
#
#   normalized_item_package_weight list_price_currency list_price_value  \
# 0                       0.500449                 USD             3.99
# 1                       0.599657                 NaN              NaN
#
#   list_price_value_with_tax        imgID                              ID_0
# 0                       NaN  51sislDjTYL  9cd726a519754b6bad27be39bc95cac6
# 1                       NaN  41MsGCednqL  44a997b7ff9f4d2ebd1615ac5f3861ff
#
# [2 rows x 34 columns]

# %%
# Print size of test set
print(f"Size of test set: {len(test)}")

# Show the first rows of test data
test.head(2)
# Out:
# Size of test set: 12131
#       ID  marketplace_id          product_type  \
# 0  17912               1  HEALTH_PERSONAL_CARE
# 1  36819               1                BEAUTY
#
#                                            item_name  \
# 0  ChicShop US 9.9 Inch Soft Penî's Lifelike Wate...
# 1  Zink Color Multi Purpose Glitter Brilliance Pr...
#
#                                  product_description  \
# 0  The products sold are all shipped confidential...
# 1     Z!NK COLORGlitter Brilliance Pro Emerald Green
#
#                                         bullet_point            brand  \
# 0  Perfect Gift: Dīldɔ suitable for beginners and...      ChicShop US
# 1                         Size: 5 gram gem shape jar  Zink Color inc.
#
#   manufacturer            part_number model_number  ...  \
# 0  ChicShop US            ChicShop US          NaN  ...
# 1   Zink Color  emerald green glitter          NaN  ...
#
#   item_dimensions_height item_dimensions_width item_dimensions_length  \
# 0                    NaN                   NaN                    NaN
# 1                    1.0                   1.0                    1.0
#
#   normalized_item_weight normalized_item_package_weight list_price_currency  \
# 0               1.763698                            NaN                 NaN
# 1               0.011023                       0.022046                 USD
#
#   list_price_value list_price_value_with_tax        imgID  \
# 0              NaN                       NaN  41I-gf3fB+L
# 1             5.99                       NaN  61OqJD7jjnL
#
#                                ID_0
# 0  49c30d495bb74a5e9ed988d4dffe9e23
# 1  dd82ff42aba547f6bdd0946ca5f61746
#
# [2 rows x 33 columns]

# %% [markdown]
# ## 3. <a name="5">Train and Validation split (Optional)</a>
#
# For unbiased evaluation, we want to split the training set into train and validation datasets. Also, it is good practice to create a small sample dataset to quickly run AutoGluon before using the full dataset.

# %%
# Take a sample of 1000 datapoints for a quick test
train_sample_small = train.sample(n=1000, random_state=1)

# For the small sample, we create a train & validation split
train_data_small, val_data_small = train_test_split(
    train_sample_small, test_size=0.1, shuffle=True, random_state=23
)

# %% [markdown]
# ## 4. <a name="5">Training our model</a>
#
# We can train a model using AutoGluon with only a single line of code.  All we need to do is tell it what column from the dataset we are trying to predict, and what the dataset is.
#
# We are going to use only the small sample from our train dataset containing 1000 data points in order to train faster.

# %%
# We specify train and validation data for the model training
first_predictor = TabularPredictor(label="label").fit(
    train_data=train_data_small, tuning_data=val_data_small
)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20210909_205717/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20210909_205717/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    900
# Train Data Columns: 33
# Tuning Data Rows:    100
# Tuning Data Columns: 33
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'multiclass' (because dtype of label-column == int, but few unique label-values observed).
# 	3 unique label values:  [1, 2, 0]
# 	If 'multiclass' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Train Data Class Count: 3
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    62723.1 MB
# 	Train Data (Original)  Memory Usage: 2.44 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 		Fitting TextSpecialFeatureGenerator...
# 			Fitting BinnedFeatureGenerator...
# 			Fitting DropDuplicatesFeatureGenerator...
# 		Fitting TextNgramFeatureGenerator...
# 			Fitting CountVectorizer for text features: ['item_name', 'product_description', 'bullet_point', 'generic_keyword', 'style']
# 			CountVectorizer fit with vocabulary size = 629
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Useless Original Features (Count: 2): ['marketplace_id', 'list_price_value_with_tax']
# 		These features carry no predictive signal and should be manually investigated.
# 		This is typically a feature which has the same value for all rows.
# 		These features do not need to be present at inference time.
# 	Unused Original Features (Count: 2): ['imgID', 'ID_0']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('object', []) : 2 | ['imgID', 'ID_0']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])        :  9 | ['number_of_items', 'case_pack_quantity', 'item_package_quantity', 'item_dimensions_height', 'item_dimensions_width', ...]
# 		('int', [])          :  1 | ['ID']
# 		('object', [])       : 14 | ['product_type', 'brand', 'manufacturer', 'part_number', 'model_number', ...]
# 		('object', ['text']) :  5 | ['item_name', 'product_description', 'bullet_point', 'generic_keyword', 'style']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])                    :  13 | ['product_type', 'brand', 'manufacturer', 'part_number', 'model_number', ...]
# 		('category', ['text_as_category'])  :   4 | ['product_description', 'bullet_point', 'generic_keyword', 'style']
# 		('float', [])                       :   9 | ['number_of_items', 'case_pack_quantity', 'item_package_quantity', 'item_dimensions_height', 'item_dimensions_width', ...]
# 		('int', [])                         :   1 | ['ID']
# 		('int', ['binned', 'text_special']) :  94 | ['item_name.char_count', 'item_name.word_count', 'item_name.capital_ratio', 'item_name.lower_ratio', 'item_name.digit_ratio', ...]
# 		('int', ['bool'])                   :   1 | ['list_price_currency']
# 		('int', ['text_ngram'])             : 630 | ['__nlp__.10', '__nlp__.100', '__nlp__.12', '__nlp__.15', '__nlp__.16', ...]
# 	5.3s = Fit runtime
# 	29 features in original data used to generate 752 features in processed data.
# 	Train Data (Processed) Memory Usage: 1.46 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 5.44s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric argument of fit()
# Fitting 13 L1 models ...
# Fitting model: KNeighborsUnif ...
# 	0.51	 = Validation score   (accuracy)
# 	0.41s	 = Training   runtime
# 	0.62s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	0.53	 = Validation score   (accuracy)
# 	0.03s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# No improvement since epoch 6: early stopping
# 	0.74	 = Validation score   (accuracy)
# 	15.2s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: LightGBMXT ...
# 	0.74	 = Validation score   (accuracy)
# 	1.85s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: LightGBM ...
# 	0.74	 = Validation score   (accuracy)
# 	1.58s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: RandomForestGini ...
# 	0.71	 = Validation score   (accuracy)
# 	1.66s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: RandomForestEntr ...
# 	0.73	 = Validation score   (accuracy)
# 	1.44s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: CatBoost ...
# 	0.74	 = Validation score   (accuracy)
# 	6.48s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: ExtraTreesGini ...
# 	0.71	 = Validation score   (accuracy)
# 	1.34s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: ExtraTreesEntr ...
# 	0.71	 = Validation score   (accuracy)
# 	1.33s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: XGBoost ...
# 	0.72	 = Validation score   (accuracy)
# 	2.78s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetMXNet ...
# 	0.7	 = Validation score   (accuracy)
# 	12.03s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# 	0.77	 = Validation score   (accuracy)
# 	4.73s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	0.77	 = Validation score   (accuracy)
# 	0.4s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 60.58s ...
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20210909_205717/")

# %% [markdown]
# ## 5. <a name="5">AutoGluon Results</a>
# Now let's take a look at all the training information AutoGluon provides via its __leaderboard function__. <br/>

# %%
first_predictor.leaderboard(silent=True)
# Out:
#                   model  score_val  pred_time_val   fit_time  \
# 0         LightGBMLarge       0.77       0.035500   4.728991
# 1   WeightedEnsemble_L2       0.77       0.036028   5.128941
# 2              LightGBM       0.74       0.034194   1.577940
# 3            LightGBMXT       0.74       0.034866   1.851772
# 4              CatBoost       0.74       0.067553   6.483831
# 5       NeuralNetFastAI       0.74       0.246855  15.204956
# 6      RandomForestEntr       0.73       0.116251   1.443754
# 7               XGBoost       0.72       0.017889   2.779312
# 8        ExtraTreesEntr       0.71       0.115485   1.330225
# 9        ExtraTreesGini       0.71       0.115989   1.337786
# 10     RandomForestGini       0.71       0.117726   1.662591
# 11       NeuralNetMXNet       0.70       0.213712  12.030862
# 12       KNeighborsDist       0.53       0.104549   0.027739
# 13       KNeighborsUnif       0.51       0.623332   0.407227
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.035500           4.728991            1       True
# 1                 0.000527           0.399950            2       True
# 2                 0.034194           1.577940            1       True
# 3                 0.034866           1.851772            1       True
# 4                 0.067553           6.483831            1       True
# 5                 0.246855          15.204956            1       True
# 6                 0.116251           1.443754            1       True
# 7                 0.017889           2.779312            1       True
# 8                 0.115485           1.330225            1       True
# 9                 0.115989           1.337786            1       True
# 10                0.117726           1.662591            1       True
# 11                0.213712          12.030862            1       True
# 12                0.104549           0.027739            1       True
# 13                0.623332           0.407227            1       True
#
#     fit_order
# 0          13
# 1          14
# 2           5
# 3           4
# 4           8
# 5           3
# 6           7
# 7          11
# 8          10
# 9           9
# 10          6
# 11         12
# 12          2
# 13          1

# %% [markdown]
# ## 6. <a name="5">Making a Prediction</a>
# Now that our model is trained, let's use it to predict the labels for the test dataset.

# %%
prediction = first_predictor.predict(test)
print(f"Predictions for the first 20 data points in the test dataset: {prediction.values[0:20]}")
# Out:
# Predictions for the first 20 data points in the test dataset: [2 2 2 2 2 2 2 1 2 2 1 0 2 2 2 2 2 2 2 2]

# %% [markdown]
# ## 7. <a name="5">Submission to our MLU Leaderboard</a>
# For this example, we will submit to the Units of Measurement Challenge on Leaderboard. The link for this challenge is https://leaderboard.corp.amazon.com/tasks/724.

# %%
# Creating a new dataframe for the submission
submission = test[["ID"]].copy(deep=True)

# Creating label column from price prediction list
submission["label"] = prediction

# Saving our csv file for Leaderboard submission
# index=False prevents printing the row IDs as separate values
submission.to_csv(
    ".././datasets/predictions/UOMI_Prediction_to_Leaderboard_First_Predictor.csv",
    index=False,
)

# %%
# Inspect the first rows of our submission file
submission.head()
# Out:
#       ID  label
# 0  17912      2
# 1  36819      2
# 2  15782      2
# 3   6565      2
# 4  33314      2

# %% [markdown]
# Run the cell below to check if your submission file has the right IDs for MLU Leaderbord.

# %%
print("Double-check submission file against the original test file...")
check_submission = TabularDataset(".././datasets/uomi-test.csv")
print(
    "Differences between project result IDs and sample submission IDs:",
    (check_submission["ID"] != submission["ID"]).sum(),
)
# Out:
# Double-check submission file against the original test file...
# Loaded data from: .././datasets/uomi-test.csv | Columns = 33 / 33 | Rows = 12131 -> 12131
# Differences between project result IDs and sample submission IDs: 0

# %% [markdown]
# ## 8. <a name="5">Re-Train with full data and predict again</a>

# %%
import os
os.environ['AUTOGLUON_TEXT_TRAIN_WITHOUT_GPU']='1'

# Retrain the model using all training data 
# We let AutoGluon perform the train/validation split directly
second_predictor = TabularPredictor(label="label").fit(
    train_data=train, time_limit = 60*20
) 

prediction = second_predictor.predict(test)

# Creating a new dataframe for the submission
submission = test[["ID"]].copy(deep=True)

# Creating label column from price prediction list
submission["label"] = prediction

# Saving our csv file for Leaderboard submission
# index=False prevents printing the row IDs as seperate values
submission.to_csv(
    ".././datasets/predictions/UOMI_Prediction_to_Leaderboard_Second_Predictor.csv",
    index=False,
)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20210909_205826/"
# Beginning AutoGluon training ... Time limit = 1200s
# AutoGluon will save models to "AutogluonModels/ag-20210909_205826/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    28305
# Train Data Columns: 33
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'multiclass' (because dtype of label-column == int, but few unique label-values observed).
# 	3 unique label values:  [1, 2, 0]
# 	If 'multiclass' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Train Data Class Count: 3
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    59847.97 MB
# 	Train Data (Original)  Memory Usage: 69.35 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 		Fitting TextSpecialFeatureGenerator...
# 			Fitting BinnedFeatureGenerator...
# 			Fitting DropDuplicatesFeatureGenerator...
# 		Fitting TextNgramFeatureGenerator...
# 			Fitting CountVectorizer for text features: ['item_name', 'product_description', 'bullet_point', 'generic_keyword']
# 			CountVectorizer fit with vocabulary size = 10000
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Useless Original Features (Count: 1): ['marketplace_id']
# 		These features carry no predictive signal and should be manually investigated.
# 		This is typically a feature which has the same value for all rows.
# 		These features do not need to be present at inference time.
# 	Unused Original Features (Count: 1): ['ID_0']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('object', []) : 1 | ['ID_0']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])        : 10 | ['number_of_items', 'case_pack_quantity', 'item_package_quantity', 'item_dimensions_height', 'item_dimensions_width', ...]
# 		('int', [])          :  1 | ['ID']
# 		('object', [])       : 16 | ['product_type', 'brand', 'manufacturer', 'part_number', 'model_number', ...]
# 		('object', ['text']) :  4 | ['item_name', 'product_description', 'bullet_point', 'generic_keyword']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])                    :    15 | ['product_type', 'brand', 'manufacturer', 'part_number', 'model_number', ...]
# 		('category', ['text_as_category'])  :     4 | ['item_name', 'product_description', 'bullet_point', 'generic_keyword']
# 		('float', [])                       :    10 | ['number_of_items', 'case_pack_quantity', 'item_package_quantity', 'item_dimensions_height', 'item_dimensions_width', ...]
# 		('int', [])                         :     1 | ['ID']
# 		('int', ['binned', 'text_special']) :    98 | ['item_name.char_count', 'item_name.word_count', 'item_name.capital_ratio', 'item_name.lower_ratio', 'item_name.digit_ratio', ...]
# 		('int', ['bool'])                   :     1 | ['list_price_currency']
# 		('int', ['text_ngram'])             : 10001 | ['__nlp__.00', '__nlp__.000', '__nlp__.01', '__nlp__.02', '__nlp__.05', ...]
# 	66.9s = Fit runtime
# 	31 features in original data used to generate 10130 features in processed data.
# 	Train Data (Processed) Memory Usage: 572.34 MB (1.0% of available memory)
# Data preprocessing and feature engineering runtime = 70.08s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric argument of fit()
# Automatically generating train/validation split with holdout_frac=0.08832361773538244, Train Rows: 25805, Val Rows: 2500
# Fitting 13 L1 models ...
# Fitting model: KNeighborsUnif ... Training model for up to 1129.92s of the 1129.26s of remaining time.
# 	0.522	 = Validation score   (accuracy)
# 	4.06s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: KNeighborsDist ... Training model for up to 1125.09s of the 1124.45s of remaining time.
# 	0.5416	 = Validation score   (accuracy)
# 	3.84s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: NeuralNetFastAI ... Training model for up to 1120.49s of the 1119.86s of remaining time.
# 	Time limit exceeded... Skipping NeuralNetFastAI.
# Fitting model: LightGBMXT ... Training model for up to 492.21s of the 491.58s of remaining time.
# 	0.868	 = Validation score   (accuracy)
# 	76.01s	 = Training   runtime
# 	0.6s	 = Validation runtime
# Fitting model: LightGBM ... Training model for up to 414.85s of the 414.22s of remaining time.
# 	0.8684	 = Validation score   (accuracy)
# 	55.9s	 = Training   runtime
# 	0.57s	 = Validation runtime
# Fitting model: RandomForestGini ... Training model for up to 357.65s of the 357.02s of remaining time.
# 	0.8272	 = Validation score   (accuracy)
# 	58.68s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: RandomForestEntr ... Training model for up to 297.76s of the 297.12s of remaining time.
# 	0.8208	 = Validation score   (accuracy)
# 	51.77s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: CatBoost ... Training model for up to 244.77s of the 244.13s of remaining time.
# 	Many features detected (10130), dynamically setting 'colsample_bylevel' to 0.09871668311944719 to speed up training (Default = 1).
# 	To disable this functionality, explicitly specify 'colsample_bylevel' in the model hyperparameters.
# 	0.8608	 = Validation score   (accuracy)
# 	119.13s	 = Training   runtime
# 	0.7s	 = Validation runtime
# Fitting model: ExtraTreesGini ... Training model for up to 124.25s of the 123.59s of remaining time.
# 	0.8128	 = Validation score   (accuracy)
# 	75.71s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: ExtraTreesEntr ... Training model for up to 47.13s of the 46.47s of remaining time.
# 	Warning: Reducing model 'n_estimators' from 300 -> 143 due to low time. Expected time usage reduced from 92.4s -> 47.1s...
# 	0.8096	 = Validation score   (accuracy)
# 	40.21s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: XGBoost ... Training model for up to 5.89s of the 5.24s of remaining time.
# 	0.7896	 = Validation score   (accuracy)
# 	16.11s	 = Training   runtime
# 	0.52s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the -19.53s of remaining time.
# 	0.872	 = Validation score   (accuracy)
# 	0.57s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 1222.38s ...
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20210909_205826/")

# %% [markdown]
# ## 9. <a name="5">Before You Go</a>
# After you are done with this Hands On, you can clean model artifacts by uncommenting and executing the cell below.
#
# __It is always good practice to clean everything when you are done, preventing the disk from getting full.__

# %%
# !rm -rf AutogluonModels
